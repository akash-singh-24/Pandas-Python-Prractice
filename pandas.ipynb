# %%
import pandas as pd
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)
df = pd.read_csv('export.csv')
df.head()
# Out:
#                                 user_id         day variantName  \
# 0  0001b7f4-0b10-4e48-a088-89d1036122bb  2024-06-29     control
# 1  0001b7f4-0b10-4e48-a088-89d1036122bb  2024-06-29     control
# 2  00100903-e150-4486-a894-f830830a37df  2024-06-29     control
# 3  00100903-e150-4486-a894-f830830a37df  2024-06-29     control
# 4  00100903-e150-4486-a894-f830830a37df  2024-06-29     control
#
#        order_code             category_name subcategory_name  user_flag  \
# 0  9A25AHNEL27993                  unlisted         Sampling  Pass User
# 1  9A25AHNEL27993                  Munchies      Energy Bars  Pass User
# 2  81BBADCPS80317      Cold Drinks & Juices      Soft Drinks  Pass User
# 3  81BBADCPS80317  Frozen Food & Ice Creams      Single Pack  Pass User
# 4  81BBADCPS80317            Sweet Cravings       Chocolates  Pass User
#
#     gsv1   gmv1   margin_v1  units      gppb1  promo_v  promo_v_on  \
# 0    0.0    0.0    0.000000      1   0.000000      0.0         0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141259 entries, 0 to 141258
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           141259 non-null  object
#  1   day               141259 non-null  object
#  2   variantName       141259 non-null  object
#  3   order_code        141259 non-null  object
#  4   category_name     141259 non-null  object
#  5   subcategory_name  141259 non-null  object
#  6   user_flag         141259 non-null  object
#  7   gsv1              141259 non-null  float64
#  8   gmv1              141259 non-null  float64
#  9   margin_v1         141201 non-null  float64
#  10  units             141259 non-null  int64
#  11  gppb1             141259 non-null  float64
#  12  promo_v           141259 non-null  float64
#  13  promo_v_on        141259 non-null  float64
#  14  promo_v_pass      141259 non-null  float64
# dtypes: float64(7), int64(1), object(7)
# ...

# %%
df['category_name'].unique()
# Out:
# array(['unlisted', 'Munchies', 'Cold Drinks & Juices',
#        'Frozen Food & Ice Creams', 'Sweet Cravings', 'Paan Corner',
#        'Breakfast & Sauces', 'Dairy, Bread & Eggs', 'Fruits & Vegetables',
#        'Stationery & Crafts', 'Atta, Rice, Oil & Dals',
#        'Masala, Dry Fruits & More', 'Electricals & Accessories',
#        'Cleaning Essentials', 'Home Needs', 'Biscuits', 'Baby Care',
#        'Toys', 'Packaged Food', 'Bath, Body & Hair',
#        'Apparel & Lifestyle', 'Hygiene & Wellness', 'Grooming Essentials',
#        'Meats, Fish & Eggs', 'Skincare', 'Tea, Coffee & More', 'Pet Care',
#        'Kitchenware and Appliances', 'Makeup & Beauty', 'Jewellery'],
#       dtype=object)

# %%
df.category_name.unique()
# Out:
# array(['unlisted', 'Munchies', 'Cold Drinks & Juices',
#        'Frozen Food & Ice Creams', 'Sweet Cravings', 'Paan Corner',
#        'Breakfast & Sauces', 'Dairy, Bread & Eggs', 'Fruits & Vegetables',
#        'Stationery & Crafts', 'Atta, Rice, Oil & Dals',
#        'Masala, Dry Fruits & More', 'Electricals & Accessories',
#        'Cleaning Essentials', 'Home Needs', 'Biscuits', 'Baby Care',
#        'Toys', 'Packaged Food', 'Bath, Body & Hair',
#        'Apparel & Lifestyle', 'Hygiene & Wellness', 'Grooming Essentials',
#        'Meats, Fish & Eggs', 'Skincare', 'Tea, Coffee & More', 'Pet Care',
#        'Kitchenware and Appliances', 'Makeup & Beauty', 'Jewellery'],
#       dtype=object)

# %%
df['category_name'].value_counts()
# Out:
# category_name
# Dairy, Bread & Eggs           32301
# Fruits & Vegetables           18718
# unlisted                      14981
# Munchies                      10978
# Atta, Rice, Oil & Dals         9156
# Cold Drinks & Juices           8302
# Biscuits                       5936
# Masala, Dry Fruits & More      5909
# Sweet Cravings                 4560
# Packaged Food                  3918
# Frozen Food & Ice Creams       3854
# Cleaning Essentials            3710
# Hygiene & Wellness             2737
# Breakfast & Sauces             2354
# Home Needs                     2223
# Tea, Coffee & More             1770
# Bath, Body & Hair              1636
# Paan Corner                    1466
# Stationery & Crafts             949
# Skincare                        930
# Meats, Fish & Eggs              800
# Grooming Essentials             728
# Electricals & Accessories       619
# Makeup & Beauty                 615
# Baby Care                       572
# ...

# %%
df.loc[0:2,'user_id':'user_flag']
# Out:
#                                 user_id         day variantName  \
# 0  0001b7f4-0b10-4e48-a088-89d1036122bb  2024-06-29     control
# 1  0001b7f4-0b10-4e48-a088-89d1036122bb  2024-06-29     control
# 2  00100903-e150-4486-a894-f830830a37df  2024-06-29     control
#
#        order_code         category_name subcategory_name  user_flag
# 0  9A25AHNEL27993              unlisted         Sampling  Pass User
# 1  9A25AHNEL27993              Munchies      Energy Bars  Pass User
# 2  81BBADCPS80317  Cold Drinks & Juices      Soft Drinks  Pass User

# %%
df[ (df['order_code'] == '9A25AHNEL27993') & (df['category_name'] == 'Munchies')]
# Out:
#                                 user_id         day variantName  \
# 1  0001b7f4-0b10-4e48-a088-89d1036122bb  2024-06-29     control
#
#        order_code category_name subcategory_name  user_flag   gsv1   gmv1  \
# 1  9A25AHNEL27993      Munchies      Energy Bars  Pass User  299.0  420.0
#
#     margin_v1  units      gppb1  promo_v  promo_v_on  promo_v_pass
# 1  113.165436      3  62.745436     47.6        35.0          11.2

# %%
df.loc[(df['order_code'] == '9A25AHNEL27993') & (df['category_name'] == 'Munchies')]
# Out:
#                                 user_id         day variantName  \
# 1  0001b7f4-0b10-4e48-a088-89d1036122bb  2024-06-29     control
#
#        order_code category_name subcategory_name  user_flag   gsv1   gmv1  \
# 1  9A25AHNEL27993      Munchies      Energy Bars  Pass User  299.0  420.0
#
#     margin_v1  units      gppb1  promo_v  promo_v_on  promo_v_pass
# 1  113.165436      3  62.745436     47.6        35.0          11.2

# %%
df.loc[(df['order_code'] == '9A25AHNEL27993') & ( df['category_name'] == 'Munchies' ) ]
# Out:
#                                 user_id         day variantName  \
# 1  0001b7f4-0b10-4e48-a088-89d1036122bb  2024-06-29     control
#
#        order_code category_name subcategory_name  user_flag   gsv1   gmv1  \
# 1  9A25AHNEL27993      Munchies      Energy Bars  Pass User  299.0  420.0
#
#     margin_v1  units      gppb1  promo_v  promo_v_on  promo_v_pass
# 1  113.165436      3  62.745436     47.6        35.0          11.2

# %%
df[df['subcategory_name'].str.contains('Drinks', na = False) & (df['variantName'] == 'control') & (df['units'] > 1)]
# Out:
#                                      user_id         day variantName  \
# 59      00761d2c-d586-46f2-9c37-5b08b98c9f95  2024-06-29     control
# 162     0176d02f-badf-4f9b-b520-af37aded7425  2024-06-29     control
# 390     02cd5f36-1760-4bf7-966d-8b681b786e7a  2024-06-29     control
# 563     041a4822-9e42-4737-8ba0-d90b13753de7  2024-06-29     control
# 757     059f2d1e-6941-4787-ac0e-aaca8d08a502  2024-06-29     control
# ...                                      ...         ...         ...
# 140768  f68e1be8-0f5d-44be-a61e-14143e2aec75  2024-06-29     control
# 140870  f7d8ed14-0d3c-4c83-8ec8-cbf1596eb938  2024-06-29     control
# 140959  f9316d12-66fd-4224-8978-d538e7e76208  2024-06-29     control
# 140996  fa34cf45-429a-4013-87ad-560a46c3dccd  2024-06-29     control
# 141051  fb3a9a90-0bd0-45d3-a724-9bdbeb7c1aff  2024-06-29     control
#
#             order_code         category_name       subcategory_name  \
# 59      9A25ADVPI44428  Cold Drinks & Juices            Soft Drinks
# ...

# %%
category_list = ['Fruits & Vegetables','Munchies']
df[df['category_name'].isin(category_list)]
# Out:
#                                      user_id         day variantName  \
# 1       0001b7f4-0b10-4e48-a088-89d1036122bb  2024-06-29     control
# 8       00150395-0d10-4f1b-b3b9-c1d8844da8c5  2024-06-29     control
# 11      001661ba-c2a4-481b-9df2-c2b5ee99b833  2024-06-29     control
# 13      00197526-c25b-48e6-a566-bc378fd0c1fa  2024-06-29     control
# 16      001b969c-45ed-425f-95e8-712264d89e13  2024-06-29     control
# ...                                      ...         ...         ...
# 141221  ff8f6349-ee20-4a6c-a00b-123602147fab  2024-06-29       Test2
# 141222  ff8f6349-ee20-4a6c-a00b-123602147fab  2024-06-29       Test2
# 141223  ff8f6349-ee20-4a6c-a00b-123602147fab  2024-06-29       Test2
# 141229  ff954cf0-2d0f-4921-95ee-a2110640e6f7  2024-06-29     control
# 141230  ff954cf0-2d0f-4921-95ee-a2110640e6f7  2024-06-29     control
#
#             order_code        category_name           subcategory_name  \
# ...

# %%
grouped = df.groupby(['variantName','category_name'])

# %%
grouped[['gmv1','gsv1','units']].mean()
# Out:
#                                                gmv1        gsv1     units
# variantName category_name
# Test1       Apparel & Lifestyle          861.960784  364.627451  1.117647
#             Atta, Rice, Oil & Dals       275.042915  221.842105  1.284211
#             Baby Care                    630.612500  434.175000  1.225000
#             Bath, Body & Hair            265.728070  210.407895  1.149123
#             Biscuits                      92.250299   71.710180  1.433533
#             Breakfast & Sauces           197.232026  157.026144  1.218954
#             Cleaning Essentials          250.634633  208.356394  1.201258
#             Cold Drinks & Juices         110.815710   98.975076  1.871601
#             Dairy, Bread & Eggs           97.603657   90.332893  1.626570
#             Electricals & Accessories    920.766990  351.980583  1.165049
#             Frozen Food & Ice Creams     194.308777  167.297806  1.625392
# ...

# %%
result = df.groupby(['variantName','category_name']).agg({
    'gmv1': 'sum',
    'order_code': 'count'
})

# %%
results = result.rename(columns = {'gmv1':'revenue','order_code':'order_count'})

# %%
results
# Out:
#                                            revenue  order_count
# variantName category_name
# Test1       Apparel & Lifestyle           43960.00           51
#             Atta, Rice, Oil & Dals       339678.00         1235
#             Baby Care                     50449.00           80
#             Bath, Body & Hair             60586.00          228
#             Biscuits                      77029.00          835
#             Breakfast & Sauces            60353.00          306
#             Cleaning Essentials          119552.72          477
#             Cold Drinks & Juices         146720.00         1324
#             Dairy, Bread & Eggs          443023.00         4539
#             Electricals & Accessories     94839.00          103
#             Frozen Food & Ice Creams     123969.00          638
#             Fruits & Vegetables          348045.00         2624
#             Grooming Essentials           41375.00          107
# ...

# %%
results['aov'] = results['revenue']/results['order_count']

# %%
results
# Out:
#                                            revenue  order_count          aov
# variantName category_name
# Test1       Apparel & Lifestyle           43960.00           51   861.960784
#             Atta, Rice, Oil & Dals       339678.00         1235   275.042915
#             Baby Care                     50449.00           80   630.612500
#             Bath, Body & Hair             60586.00          228   265.728070
#             Biscuits                      77029.00          835    92.250299
#             Breakfast & Sauces            60353.00          306   197.232026
#             Cleaning Essentials          119552.72          477   250.634633
#             Cold Drinks & Juices         146720.00         1324   110.815710
#             Dairy, Bread & Eggs          443023.00         4539    97.603657
#             Electricals & Accessories     94839.00          103   920.766990
#             Frozen Food & Ice Creams     123969.00          638   194.308777
# ...
